# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.functions import col , when
import os
from os import listdir
from pyspark.sql.types import StructType,StructField, StringType , LongType
import numpy as np
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
spark = SparkSession.builder.config("spark.driver.memory","5g").getOrCreate()

# %%
path= "C:\\log_content\\"

# %%
def retrieve_data_from_source(path,filename):
    print("------------------------------------------")
    print("Retrieving data from source")
    print("------------------------------------------")
    df = spark.read.json(path+filename)
    df = df.select('_source.*')
    df.show()
    print("Processed data of {}".format(filename))
    return df

# %%
def preprocess_data(df):
    print("------------------------------------------")
    print("Categorizing data")
    print("------------------------------------------")
    df = df.withColumn("Type",
           when((col("AppName") == 'CHANNEL') | (col("AppName") =='DSHD')| (col("AppName") =='KPLUS')| (col("AppName") =='KPlus'), "Truyền Hình")
          .when((col("AppName") == 'VOD') | (col("AppName") =='FIMS_RES')| (col("AppName") =='BHD_RES')|
                 (col("AppName") =='VOD_RES')| (col("AppName") =='FIMS')| (col("AppName") =='BHD')| (col("AppName") =='DANET'), "Phim Truyện")
          .when((col("AppName") == 'RELAX'), "Giải Trí")
          .when((col("AppName") == 'CHILD'), "Thiếu Nhi")
          .when((col("AppName") == 'SPORT'), "Thể Thao")
          .otherwise("Error"))
    df.show()
    print("------------------------------------------")
    print("Finalizing data")
    print("------------------------------------------")
    df = df.select('Contract','Type','TotalDuration')
    df.show()
    return df

# %%
def pivot_data(df):
    print("------------------------------------------")
    print("Pivoting data")
    print("------------------------------------------")
    df = df.groupBy('Contract','Type').sum().withColumnRenamed('sum(TotalDuration)','TotalDuration')
    df_pivot = df.groupBy("Contract").pivot("Type").sum("TotalDuration")
    df_pivot.show()
    return df_pivot

# %%
def processing_data(df):
    df = preprocess_data(df)
    df = pivot_data(df)
    return df

# %%
def load(df):
    try:
        df.write.mode("overwrite") \
        .format("jdbc") \
        .option("url","jdbc:postgresql://localhost:5432/logcontent?user=etl&password=demopass") \
        .option("user", "etl") \
        .option("password", "demopass") \
        .option("driver", "org.postgresql.Driver") \
        .option("logcontent","table") \
        .save()
        print("Data imported successful")
    except Exception as e:
        print("Data load error: " + str(e))

# %%
def main_task(path):
    file_list = listdir(path)
    emp_RDD = spark.sparkContext.emptyRDD()
    schema = StructType([
      StructField('AppName', StringType(), True),
      StructField('Contract', StringType(), True),
      StructField('Mac', StringType(), True),
      StructField('TotalDuration',LongType(), True)
      ])
    df = spark.createDataFrame(data= emp_RDD,schema=schema)
    for i in file_list:
        df1 = retrieve_data_from_source(path,i)
        df = df.union(df1)
    df = processing_data(df)
    pdf= df.toPandas()
    engine = create_engine("postgresql+psycopg2://etl:demopass@localhost/logcontent?client_encoding=utf8")
    pdf.to_sql('Newtable', engine, index=False, if_exists='replace')
    return print("Task Run successfully")

# %%
main_task(path)
# Out:
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |  KPLUS|HNH579912|0C96E62FC55C|          254|
# |  KPLUS|HUFD40665|CCEDDC333614|         1457|
# |  KPLUS|HNH572635|B068E6A1C5F6|         2318|
# |  KPLUS|HND141717|08674EE8D2C2|         1452|
# |  KPLUS|HNH743103|402343C25D7D|          251|
# |  KPLUS|HNH893773|B84DEE76D3B8|          924|
# |  KPLUS|HND083642|B84DEE849A0F|         1444|
# |  KPLUS|DNFD74404|90324BB44C39|          691|
# |  KPLUS|DTFD21200|B84DEED27709|         1436|
# |  KPLUS|LDFD05747|0C96E6C95E53|         1434|
# |  KPLUS|HNH063566|B84DEEDD1C85|          687|
# |  KPLUS|HNH866786|10394E2790A5|          248|
# |  KPLUS|NBAAA1128|10394E47C1AF|          247|
# |  KPLUS|HNH960439|B84DEED34371|          683|
# |  KPLUS|HNJ035736|CCD4A1FA86A5|          246|
# |  KPLUS|NTFD93673|B84DEEEF4763|         2288|
# |  KPLUS|HNJ063267|10394E172CA7|         2282|
# |  KPLUS|HNH790383|4CEBBD53378B|          906|
# |  KPLUS|THFD12466|5CEA1D893E1C|          242|
# |  KPLUS|HNH566080|802BF9E0DDC0|          242|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220401.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|DTFD19291|B84DEE76AEFC|        46486|
# |    VOD|HDAAA2134|10394E2791E6|        13840|
# |    VOD|SGJ048834|B84DEEFB33E8|        13527|
# |    VOD|NTFD59815|C0B5D7E80AD0|         7471|
# |    VOD|HNJ144088|10394E4299DE|         1228|
# |    VOD|BNFD57616|CCD4A1FA687B|        29501|
# |    VOD|HBFD09145|B84DEE170741|        12650|
# |    VOD|HPFD56884|0C96E66A5B12|        36438|
# |    VOD|SGJ021133|10394E19A727|         6992|
# |    VOD|QND043834|B05216CFC628|        12454|
# |    VOD|SGH298600|B046FCC17838|        37187|
# |    VOD|HNFD81209|B068E6A1C0A4|        31610|
# |    VOD|HNH422200|B4B5B6FD0872|         9848|
# |    VOD|CBFD00985|B046FCB42796|        64653|
# |    VOD|KTFD02654|0C96E6575123|        14212|
# |    VOD|SGH830312|8CC84B41A000|        11734|
# |    VOD|QNFD71404|90324BB4344B|        44003|
# |    VOD|CTFD05474|A86BAD5F7B27|        51361|
# |    VOD|NTFD51783|B84DEE43F3A1|        38517|
# |    VOD|NTFD13266|B046FCBC5C7A|        75811|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220402.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|TBFD06474|84AA9C3E393E|        34120|
# |CHANNEL|HNH976100|B84DEEEF1E14|        34392|
# |CHANNEL|TVD001309|B046FCAA24FB|        34119|
# |CHANNEL|HNH434192|B05216B7B0A8|        34390|
# |CHANNEL|AGFD34246|8CC84B700501|        34389|
# |CHANNEL|HPD070711|B046FCB74FE7|        34388|
# |CHANNEL|HNH769435|E86F3850462D|        34388|
# |CHANNEL|HPFD28952|B046FCC02019|        34387|
# |CHANNEL|NBFD24516|10394E193B60|        34386|
# |CHANNEL|HNH829670|B84DEE838A56|        34386|
# |CHANNEL|QNFD64053|E86F38503BF5|        34116|
# |CHANNEL|DBD000785|B84DEED44102|        34115|
# |CHANNEL|HNJ070994|10394E13A908|        34383|
# |CHANNEL|BNFD25431|7440BB3C932A|        34114|
# |CHANNEL|NTH004362|10394E25C692|        34113|
# |CHANNEL|AGFD11028|5413794C52FD|        34113|
# |CHANNEL|BTFD10521|A86BAD942A73|        34113|
# |CHANNEL|HPFD11507|D89C67A9226B|        34382|
# |CHANNEL|BNFD25238|90324B370933|        34380|
# |CHANNEL|HTFD08128|CCD4A1FA5828|        34380|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220403.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HNJ095119|B84DEEFB4659|        48997|
# |CHANNEL|NBFD20591|B84DEE84A8CB|        48995|
# |CHANNEL|SGH497930|90324B36CE66|        48994|
# |CHANNEL|LDFD16037|84AA9CAB0C94|        48993|
# |CHANNEL|VTFD15991|9C305B3747B1|        48992|
# |CHANNEL|NTFD93962|B84DEEEF32DB|        48991|
# |CHANNEL|HNH517916|5CBAEF93A7A1|        48988|
# |CHANNEL|SGFD87036|D43A2F006C62|        48986|
# |CHANNEL|HDFD45843|08674EDCC161|        48984|
# |CHANNEL|HPFD91590|4CEBBDD751BA|        48983|
# |CHANNEL|QBFD07854|B84DEE8114B2|        48982|
# |CHANNEL|DNH022168|E4AB8977F05E|        48980|
# |CHANNEL|LDD013297|D89C67A91AF0|        48978|
# |CHANNEL|BNFD74209|10394E41B369|        48977|
# |CHANNEL|HNH741192|402343AC7501|        48975|
# |CHANNEL|NND007265|B046FCBA8381|        48973|
# |CHANNEL|BDFD81544|B046FCC363BB|        48972|
# |CHANNEL|THFD35248|D89C67459162|        48971|
# |CHANNEL|BNFD66235|10394E1EDF1F|        48969|
# |CHANNEL|SGH002179|B84DEE883CDA|        48968|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220404.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HUFD52373|B84DEED3189E|        45562|
# |CHANNEL|DLD023066|9C305B3747EC|        44928|
# |CHANNEL|HNH487875|84AA9C45BF58|        45560|
# |CHANNEL|VLFD20963|10394E19A57B|        45560|
# |CHANNEL|SGH522004|7440BB97D85F|        44926|
# |CHANNEL|HDFD26043|D46A6A45D312|        44925|
# |CHANNEL|DAD032437|B84DEED88973|        44924|
# |CHANNEL|SGJ021200|B84DEEF5CCC0|        45555|
# |CHANNEL|PYFD09600|CCEDDC37CDCE|        45554|
# |CHANNEL|        0|5413790004B5|        45552|
# |CHANNEL|SGH242594|B046FCB19443|        45551|
# |CHANNEL|DNFD79882|DCA2664E7CD8|        45549|
# |CHANNEL|BLFD15559|B84DEED8D671|        45549|
# |CHANNEL|SGH283996|B046FCC01DF6|        45548|
# |CHANNEL|STFD00766|B046FCB8911F|        45545|
# |CHANNEL|NAD028548|84AA9C3E5379|        44916|
# |CHANNEL|HPFD85426|E4AB897E88B3|        45538|
# |CHANNEL|BEFD05267|D89C670094B8|        44914|
# |CHANNEL|TGFD03094|90324B0EBE3C|        45534|
# |CHANNEL|BDFD10968|B046FCB9CA69|        44914|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220405.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|CTFD26018|7440BB880115|        39782|
# |CHANNEL|TBFD19647|4CEBBDD7543A|        39781|
# |CHANNEL|HNH956362|B84DEED2C77F|        39780|
# |CHANNEL|HND142276|08674EDF2225|        39779|
# |CHANNEL|HNH596583|4CEBBD1B627D|        39778|
# |CHANNEL|HDFD24819|4CEBBDD75E64|        39778|
# |CHANNEL|VPFD18284|B84DEECB66F8|        39776|
# |CHANNEL|DTFD23721|10394E16EA3F|        40479|
# |CHANNEL|HPH003880|B84DEE76DB47|        40478|
# |CHANNEL|PTFD10114|485F9981FFAF|        40477|
# |CHANNEL|HPFD94052|B84DEE882C88|        40476|
# |CHANNEL|SGH594351|0C96E6A9FF29|        40474|
# |CHANNEL|HNH527132|10394E41D06D|        40473|
# |CHANNEL|HND495468|1CBFC0F204AC|        40472|
# |CHANNEL|HBFD09585|4CEBBDA281A5|        40471|
# |CHANNEL|CTFD51711|10394E27B8A2|        40471|
# |CHANNEL|BGFD20370|7440BB97F868|        40469|
# |CHANNEL|CBFD00451|B046FCB23732|        40468|
# |CHANNEL|HPFD59783|08674EF3C171|        40468|
# |CHANNEL|PYFD04273|E4AB89739EC0|        40467|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220406.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|PTFD07513|90324B36ED3A|         4150|
# |    VOD|PTFD08059|7440BB3C890C|         5685|
# |    VOD|PTFD08970|802BF9E0D452|         1235|
# |    VOD|PTFD10712|08674EC9E786|         4374|
# |    VOD|PTFD11273|08674EDEE9D3|          386|
# |    VOD|PTFD12504|08674EF6EFA2|         5777|
# |    VOD|PTFD13797|08674EF79519|          423|
# |    VOD|PTFD15292|D8126535743A|          109|
# |    VOD|PTFD16422|B84DEE888E6B|         3505|
# |    VOD|PTFD18239|18473D90FA82|         3416|
# |    VOD|PTFD20149|B84DEEEF5F1E|         2537|
# |    VOD|PTFD21357|B84DEEDD197D|         1666|
# |    VOD|PTFD22780|10394E19877A|         2322|
# |    VOD|PTFD23060|10394E13AA45|         1161|
# |    VOD|PTFD25107|10394E197E71|         3432|
# |    VOD|PYAAA0615|10394E4292D5|         2484|
# |    VOD|PYD003993|8CC84BDFBA08|         3463|
# |    VOD|PYD007913|B046FCAA1231|         3907|
# |    VOD|PYD010104|B046FCB6B5E5|         3130|
# |    VOD|PYD011309|90324B36E928|         3680|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220407.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|SGH478396|84AA9C924A55|        16813|
# |CHANNEL|QID005208|B84DEE4402AC|        16813|
# |CHANNEL|SGJ007445|B84DEEF585F1|        16813|
# |CHANNEL|DNH076438|10394E27BD0F|        16812|
# |CHANNEL|NAD021411|84AA9C3E5525|        16812|
# |CHANNEL|QIFD03902|B84DEE43A8F7|        16812|
# |CHANNEL|HYD015243|B84DEED38A63|        16812|
# |CHANNEL|HPFD69557|08674EF37205|        16811|
# |CHANNEL|HNH670857|10394E174687|        16811|
# |CHANNEL|SGH477619|90324B0EC525|        16811|
# |CHANNEL|HNH805509|B84DEE837978|        16811|
# |CHANNEL|HPFD82211|E4AB897E92FF|        16811|
# |CHANNEL|HNH904087|18473D53D5F9|        16810|
# |CHANNEL|LCFD16773|9C305BD6497B|        16810|
# |CHANNEL|HPFD35246|D46A6A45D318|        16810|
# |CHANNEL|QNH009930|10394E4B92FD|        16809|
# |CHANNEL|BDFD85883|802BF9E0CA11|        16809|
# |CHANNEL|DND074241|B046FCADDA76|        16809|
# |CHANNEL|VTFD74443|B84DEE82DFEE|        16809|
# |CHANNEL|SGH937631|B84DEED1EC7E|        16809|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220408.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|LAFD10061|7440BBEC79C7|        56756|
# |    VOD|SGH011130|802BF95B12B1|        27387|
# |    VOD|SGH416210|802BF9CF456C|        11414|
# |    VOD|HTFD05526|802BF9E0D1C1|        31250|
# |    VOD|HDFD39372|802BF9E0F6AB|        10902|
# |    VOD|SGH379247|84AA9C22C211|        34022|
# |    VOD|SGH380103|84AA9C2701DB|        13575|
# |    VOD|NTFD29953|84AA9C3316AE|        18056|
# |    VOD|SGH961648|B84DEED32C84|         2342|
# |    VOD|BDH053175|B84DEED38234|         4511|
# |    VOD|NDFD29593|B84DEED3C00B|         6856|
# |    VOD|SGJ038776|B84DEED868DA|        33323|
# |    VOD|DAFD26259|B84DEED8C0CD|        22810|
# |    VOD|KGFD32636|B84DEEDCA7B3|          929|
# |    VOD|NAD048622|B84DEEEF0E74|        17142|
# |    VOD|BDFD04318|B84DEEEF3E84|         2844|
# |    VOD|SGD399160|B84DEEF5EB63|         2227|
# |    VOD|SGJ047735|B84DEEF66AFB|         8603|
# |    VOD|DAFD77744|C0B5D7E7FB5D|        15642|
# |    VOD|DLFD18853|C0B5D7E8104B|         1804|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220409.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|CTFD21090|84AA9C45B5AB|         5026|
# |CHANNEL|HBD000995|B046FCBA1413|         5026|
# |CHANNEL|HNH225229|10394E42A649|         5026|
# |CHANNEL|HNH692767|08674EF3BEE6|         5026|
# |CHANNEL|HYFD34668|08674EF767C2|         5026|
# |CHANNEL|PTAAA2129|B4B5B6FCF156|         5026|
# |CHANNEL|SGAAG3866|D43A2F007F9C|         5026|
# |CHANNEL|SGH448746|9C305BD63574|         5026|
# |CHANNEL|SGJ140426|10394E4263CE|         5026|
# |CHANNEL|DND084045|B84DEEF5C15C|         5025|
# |CHANNEL|HDFD38049|08674EE95D77|         5025|
# |CHANNEL|HND722427|A86BAD74200D|         5025|
# |CHANNEL|HNH772428|8CC84B57C6D7|         5025|
# |CHANNEL|HNJ161559|10394E41C7E8|         5025|
# |CHANNEL|NDAAA1380|10394E4B06C8|         5025|
# |CHANNEL|SGD716591|E4AB89212A49|         5025|
# |CHANNEL|SGJ109922|0C96E60B4F03|         5025|
# |CHANNEL|BEFD21274|CCEDDC981F69|         5024|
# |CHANNEL|GLFD06673|ACD564679689|         5024|
# |CHANNEL|HND671757|CCEDDC5E380D|         5024|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220410.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|HPFD65148|08674EDECC82|        22008|
# |    VOD|SGH937774|B84DEED19832|        13544|
# |    VOD|TBD015237|B84DEE8888E5|        12478|
# |    VOD|SGH904187|CCEDDC37EC2D|        10850|
# |    VOD|NTFD96166|B84DEEF5D6D2|        15605|
# |    VOD|SGH475724|B046FCC012E9|        30628|
# |    VOD|NAFD13517|485F994D72C1|        13261|
# |    VOD|SGH609213|485F994D888D|        18692|
# |    VOD|SGH336722|B84DEED1E77F|         4578|
# |    VOD|SGH605120|485F992BD199|        22451|
# |    VOD|SGH376303|E89EB419D200|        10025|
# |    VOD|DAFD87860|E4AB8977FC14|        21318|
# |    VOD|BDD060351|10394E19B7FB|         2046|
# |    VOD|BDFD87975|18473D8EA932|        10428|
# |    VOD|TIFD01165|E4AB897E0214|        17391|
# |    VOD|TQFD06821|08674EE1EAE8|         6529|
# |    VOD|BIFD08670|9C305BD63719|        22330|
# |    VOD|SGH017957|B046FCB25BDC|        25084|
# |    VOD|SGH007834|CCEDDC5E353F|        30902|
# |    VOD|HNH408448|84AA9C28B0F6|        14367|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220411.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |  CHILD|HNH406459|84AA9C28BEAD|         8616|
# |  CHILD|HNH432398|84AA9C3FFAD3|         2012|
# |  CHILD|HNH447899|9C305B2139A1|         8410|
# |  CHILD|HNH504264|90324B36C4F6|        22356|
# |  CHILD|HNH552247|D89C67A93B79|        12037|
# |  CHILD|HNH584606|5CEA1D0A438F|        11665|
# |  CHILD|HNH612072|10394E13AE6D|         8358|
# |  CHILD|HNH638942|485F99AB1DFE|         7074|
# |  CHILD|HNH737363|402343AC7640|          447|
# |  CHILD|HNH790358|4CEBBD532B55|          401|
# |  CHILD|HNH910063|D89C670A1C9F|         7115|
# |  CHILD|HNH977180|B84DEED42D35|            0|
# |  CHILD|HNJ066285|10394E1B4BEF|         1482|
# |  CHILD|HPAAA6363|10394E47BD4D|          721|
# |  CHILD|HPFD38510|B05216B798E2|         4791|
# |  CHILD|HPFD51410|DCA266230158|        16060|
# |  CHILD|HTFD08787|84AA9C35325E|         6440|
# |  CHILD|HYD016983|10394E47AD7B|         1208|
# |  CHILD|LAD007770|B84DEE88A10D|         3878|
# |  CHILD|LCD003782|B046FCACE1C4|         2835|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220412.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|NNFD16578|08674EF71C21|        85924|
# |CHANNEL|        0|10394E1B3135|        85923|
# |CHANNEL|SGH747545|B84DEE16DDD1|        85923|
# |CHANNEL|TQFD02020|F8DA0C5AC1A5|        85923|
# |CHANNEL|NBFD22207|B84DEED19184|        85922|
# |CHANNEL|HYFD32674|E4AB891C0C69|        85921|
# |CHANNEL|SGH367569|5413791D510C|        85920|
# |CHANNEL|BGD023581|10394E172B5C|        85919|
# |CHANNEL|TNFD36386|B84DEED28267|        85919|
# |CHANNEL|HBFD04818|0C96E68E804C|        85918|
# |CHANNEL|NAD030630|A86BAD742248|        85918|
# |CHANNEL|TIFD14458|802BF95B2D7D|        85917|
# |CHANNEL|HNH817858|B046FCAD9BC7|        85915|
# |CHANNEL|SGH895431|B4B5B6FCD1A1|        85746|
# |CHANNEL|HYFD46950|B84DEED26148|        85913|
# |CHANNEL|HPFD62302|485F99C7218C|        85745|
# |CHANNEL|DLFD32011|10394E196B7A|        85744|
# |CHANNEL|DNH061393|B84DEEF5CFD8|        85910|
# |CHANNEL|HDFD70592|B84DEEF66282|        85743|
# |CHANNEL|HDFD08820|08674EE96240|        85742|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220413.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HPD075540|10394E1986B5|        49993|
# |CHANNEL|SGB200812|84AA9C35144F|        49176|
# |CHANNEL|SGH333655|F8DA0C2A3690|        49991|
# |CHANNEL|LCFD04575|28565A503101|        49171|
# |CHANNEL|HNJ106291|B84DEEF634EE|        49989|
# |CHANNEL|HNH206178|B05216501FDF|        49988|
# |CHANNEL|BTD024849|0C96E6C954B6|        49986|
# |CHANNEL|BEFD20259|CCEDDC98024B|        49985|
# |CHANNEL|HYFD31197|08674EE20282|        49983|
# |CHANNEL|HNH941055|B84DEECB4F13|        49983|
# |CHANNEL|HTFD07729|08674EDEB4D7|        49981|
# |CHANNEL|SGH455296|84AA9C45C829|        49979|
# |CHANNEL|GLFD07131|E4AB89A64C84|        49977|
# |CHANNEL|KGFD15723|E4AB893F5F3F|        49161|
# |CHANNEL|HNH792684|D81265355EA0|        49975|
# |CHANNEL|HNH540495|90324B000FAA|        49973|
# |CHANNEL|LDFD15244|90324B36B17F|        49153|
# |CHANNEL|THFD17772|485F998235A3|        49150|
# |CHANNEL|HYD008777|5CEA1DBEC594|        49149|
# |CHANNEL|HNH476441|5CEA1D893733|        49969|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220414.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|SGH740229|E4AB89738B00|          781|
# |CHANNEL|HGD003644|B84DEED1B88D|          771|
# |CHANNEL|SGH339686|E4AB891897D6|          781|
# |CHANNEL|SGH205304|10394E3D7D4E|          817|
# |CHANNEL|SGD521367|B046FCA6AF4B|          800|
# |CHANNEL|BDH025226|D81265356426|          781|
# |CHANNEL|SGH704998|08674EE8F53A|          817|
# |CHANNEL|VPFD21365|B84DEEF6491C|          781|
# |CHANNEL|QBFD03153|0C96E6AA125A|          781|
# |CHANNEL|BNFD67898|10394E1935F5|          760|
# |CHANNEL|TIFD23531|8CC84BDFA233|          781|
# |CHANNEL|HTAAA0872|10394E47FB3A|          760|
# |CHANNEL|HNH525654|84AA9C99CCFA|          771|
# |CHANNEL|SGH658197|08674EDF44DB|          760|
# |CHANNEL|SGD721494|B046FCB90D50|          781|
# |CHANNEL|SGH786941|E4AB897EA713|          760|
# |CHANNEL|DNFD22848|D46A6A45C205|          781|
# |CHANNEL|HDFD10316|B84DEED286B1|          781|
# |CHANNEL|BIFD01574|F8DA0C35B191|          799|
# |CHANNEL|SGH658775|08674EE1C931|          759|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220415.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|CTFD23516|7440BB87FB5E|        27966|
# |    VOD|DAD000423|E4AB89A64641|        22040|
# |    VOD|DAD051330|E4AB89A6591C|        27528|
# |    VOD|DAFD11908|B84DEED8C411|        13119|
# |    VOD|DAFD24923|802BF95B3C53|        19478|
# |    VOD|DAFD34702|D46A6A45D1D1|        12449|
# |    VOD|DAFD49154|90324B36D1C4|        15398|
# |    VOD|DAFD67755|08674EDCF163|         6927|
# |    VOD|DAFD81323|E4AB8927C546|        16721|
# |    VOD|DAH007266|B84DEED194C6|        19964|
# |    VOD|DAH021027|10394E17C2D3|         3111|
# |    VOD|DLAAA1236|10394E41DC5D|         5683|
# |    VOD|DLFD12929|802BF95B2D11|        21282|
# |    VOD|DLFD30902|E4AB8994E144|        11959|
# |    VOD|DND059254|B046FCA7C134|        11481|
# |    VOD|DND070747|10394E261635|         3073|
# |    VOD|DNFD13555|B046FCB83B34|        22878|
# |    VOD|DNFD23437|E4AB8973833A|        18387|
# |    VOD|DNFD46484|9C305B375D3F|        17283|
# |    VOD|DNFD71384|84AA9C8CE451|         8468|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220416.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HNH780470|D81265813A9D|        34561|
# |CHANNEL|PYFD07107|10394E2624B0|        34560|
# |CHANNEL|THD034492|B046FCACA9D0|        34714|
# |CHANNEL|BIFD07132|84AA9C26E4F5|        34558|
# |CHANNEL|SGH365576|5413794C56C7|        34713|
# |CHANNEL|HNJ085640|10394E135348|        34712|
# |CHANNEL|QNFD93507|B84DEED43CB9|        34712|
# |CHANNEL|DAFD27577|B046FCC37E2A|        34711|
# |CHANNEL|SGH444690|10394E17028F|        34710|
# |CHANNEL|TBFD10216|E4AB891C1063|        34550|
# |CHANNEL|LSFD08270|90324B36BC63|        34549|
# |CHANNEL|HUFD23210|90324BA32C10|        34548|
# |CHANNEL|SGH210223|485F99823BF3|        34547|
# |CHANNEL|DAFD52796|DCA2664E62FC|        34547|
# |CHANNEL|NTFD74376|B84DEE8867D7|        34546|
# |CHANNEL|QNFD46177|B84DEEEF618C|        34545|
# |CHANNEL|AGFD49091|10394E176D85|        34544|
# |CHANNEL|DAH026437|10394E196BA0|        34543|
# |CHANNEL|LDFD36781|90324B0ED4FE|        34543|
# |CHANNEL|TIFD30702|10394E170FC0|        34542|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220417.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|SGH441051|84AA9C3FE7E0|        39236|
# |CHANNEL|QNFD04881|E4AB898A2664|        39646|
# |CHANNEL|HNH630617|105BAD1A001D|        39645|
# |CHANNEL|HGFD14520|B84DEED319FF|        38615|
# |CHANNEL|SGD062432|B046FCB47B80|        38614|
# |CHANNEL|BDH075235|10394E199C91|        38613|
# |CHANNEL|QNFD93174|B84DEED43636|        38612|
# |CHANNEL|CMFD21717|10394E3D84B0|        38611|
# |CHANNEL|SGH445663|84AA9C3CE124|        38484|
# |CHANNEL|NDFD15319|08674EDCA50C|        38610|
# |CHANNEL|SGJ137700|10394E400891|        38483|
# |CHANNEL|HNH471858|84AA9C8F57CA|        38608|
# |CHANNEL|HGD002696|802BF95B2EA2|        39643|
# |CHANNEL|SGAAC8526|B4B5B6FC9504|        38476|
# |CHANNEL|VTFD36076|90324B0EC7A2|        38474|
# |CHANNEL|HNJ054327|10394E1EDACA|        38474|
# |CHANNEL|QNFD30185|84AA9C34FBEB|        38473|
# |CHANNEL|SGD755900|5413791D3A91|        38472|
# |CHANNEL|LDFD13325|84AA9C45A8B5|        38471|
# |CHANNEL|HUFD32772|08674EE1B7FA|        38470|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220418.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |  KPLUS|DAFD40393|B84DEE88BC1B|         1498|
# |  KPLUS|HNJ114523|B84DEED89FBA|         1497|
# |  KPLUS|HNJ141463|10394E42AEF2|         1495|
# |  KPLUS|HNH884949|10394E1ED5B4|         1493|
# |  KPLUS|HPFD21968|9453305FBC80|         1488|
# |  KPLUS|SGH604649|485F994D9F7F|         1486|
# |  KPLUS|BDFD41248|B046FCB3087B|         1484|
# |  KPLUS|HNJ041432|10394E1B2F57|         1483|
# |  KPLUS|HNH592654|0C96E66A254D|         1479|
# |  KPLUS|SGJ070931|B84DEEF64E93|         1473|
# |  KPLUS|HNH905522|18473D53D4A2|         1470|
# |  KPLUS|SGH314457|B046FCC0F55B|         1468|
# |  KPLUS|SGD799254|B84DEE84D8BA|         1465|
# |  KPLUS|DAFD78127|C0B5D7E7FCB8|         1462|
# |  KPLUS|SGH496593|08674EE19F72|         1460|
# |  KPLUS|HNH483018|84AA9C45DEE5|         1458|
# |  KPLUS|HND694493|08674EF77CA1|         1455|
# |  KPLUS|HNH931195|CCEDDC5E4B43|         1452|
# |  KPLUS|HND612199|B84DEECA9FFA|         1285|
# |  KPLUS|HNH655591|08674EDED632|         1281|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220419.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|THD018520|B046FCB6CDB0|        45048|
# |CHANNEL|HNJ128633|B84DEED91328|        45046|
# |CHANNEL|AGAAA0895|10394E3D7A86|        45044|
# |CHANNEL|HNH620330|485F99822365|        45043|
# |CHANNEL|NBFD04495|D80F992FD1D9|        45041|
# |CHANNEL|LSFD07840|90324B370C7D|        45039|
# |CHANNEL|SGH976929|B84DEED313E0|        45038|
# |CHANNEL|SGD385800|B046FCB4BEF9|        45037|
# |CHANNEL|NDFD15595|08674EDCAACF|        45036|
# |CHANNEL|KGFD23729|CCEDDC5E2AA9|        45035|
# |CHANNEL|BDH070375|10394E25B5FE|        45033|
# |CHANNEL|HDFD25064|18473DFC9F54|        45031|
# |CHANNEL|SLFD14524|B84DEECB699C|        45030|
# |CHANNEL|NDFD33342|B84DEEDCEED3|        45028|
# |CHANNEL|HNH296394|28565A50301C|        45027|
# |CHANNEL|HNH683540|08674EDFC9E0|        45026|
# |CHANNEL|LAD005101|B046FCA97A17|        45026|
# |CHANNEL|HPFD09941|B046FCB74FEE|        45025|
# |CHANNEL|LCFD15774|4CEBBDD6C4D7|        45025|
# |CHANNEL|HNH962515|10394E279948|        45025|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220420.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|SGD256159|B4B5B6FCA679|          947|
# |CHANNEL|BIFD28033|CCEDDC5E25B1|          947|
# |CHANNEL|QNFD70775|B84DEE853520|          947|
# |CHANNEL|SGAAC5250|B4B5B6FCBE89|          947|
# |CHANNEL|HNH760579|E86F3810F38D|          947|
# |CHANNEL|HUFD41938|E4AB8994F12F|          947|
# |CHANNEL|GLFD14638|08674EE1BEF3|          947|
# |CHANNEL|SGH012349|CCEDDC033F2D|          947|
# |CHANNEL|SGD308582|B046FCB25C92|          947|
# |CHANNEL|SGH301645|7440BBC0E2EA|          947|
# |CHANNEL|SGH766065|B84DEE43C19A|          947|
# |CHANNEL|HNH641085|08674EC9D0D4|          947|
# |CHANNEL|HNH034268|802BF9E0E6A4|          946|
# |CHANNEL|BDFD52807|B046FCAC7D32|          946|
# |CHANNEL|SGH296119|B046FCC06EDC|          946|
# |CHANNEL|CMD014242|E4AB8920F7A6|          946|
# |CHANNEL|GLFD04317|28565A96191D|          946|
# |CHANNEL|THFD05807|84AA9C34C26B|          946|
# |CHANNEL|GLFD01586|D89C67A91AEF|          946|
# |CHANNEL|HNH831942|B84DEE8A540A|          946|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220421.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HGAAA2371|B4B5B6FD43E8|        73731|
# |CHANNEL|HDFD70929|1CBFC0F227A8|        73728|
# |CHANNEL|NDFD28048|B84DEED214EA|        73726|
# |CHANNEL|HDD017864|0C96E6E866EC|        72775|
# |CHANNEL|HPFD26768|B84DEE854001|        76216|
# |CHANNEL|DAH009048|B84DEED1A788|        72772|
# |CHANNEL|VPFD11652|08674EF6EEEF|        72339|
# |CHANNEL|BNFD05564|B046FCB7F3D2|        74840|
# |CHANNEL|TVFD04744|A86BAD5F6EA6|        75201|
# |CHANNEL|SGH510088|B05216503306|        72335|
# |CHANNEL|HNH537301|FC017C507BCF|        72763|
# |CHANNEL|HMFD08695|8CC84BDFAB88|        76206|
# |CHANNEL|SGH596455|0C96E68E52E0|        73715|
# |CHANNEL|HDFD68836|1CBFC0F22550|        75185|
# |CHANNEL|DAH029541|B84DEED8B963|        73713|
# |CHANNEL|NBFD19133|B84DEE8823A4|        72318|
# |CHANNEL|HPD059586|4CEBBDE0620B|        74187|
# |CHANNEL|QAFD17030|10394E16EFB2|        76185|
# |CHANNEL|HYFD08034|E4AB897E89E5|        74812|
# |CHANNEL|PTFD05952|10394E13499C|        75178|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220422.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HPD060862|E86F3810D96B|        45688|
# |CHANNEL|HNH704093|E4AB891BF899|        45686|
# |CHANNEL|HNH949619|B84DEED2DE6F|        45685|
# |CHANNEL|QAFD17684|B84DEEEF43AE|        45684|
# |CHANNEL|HNH040958|D89C67D975EE|        45683|
# |CHANNEL|NDD014734|84AA9C34C468|        45682|
# |CHANNEL|HNAAG3758|10394E4B9D0F|        45681|
# |CHANNEL|HND450459|84AA9C3FF810|        45680|
# |CHANNEL|SGD152886|08674EDE9A85|        45679|
# |CHANNEL|SGAAC8170|10394E42600B|        45678|
# |CHANNEL|LSFD06716|84AA9C34BBB3|        45677|
# |CHANNEL|VTFD34314|10394E13886C|        45676|
# |CHANNEL|STD008778|C0B5D7C19CDB|        45675|
# |CHANNEL|BTFD17283|84AA9CA5B1B9|        45672|
# |CHANNEL|KGFD11438|08674ECA12A6|        45672|
# |CHANNEL|LCAAA1083|B4B5B6FC916E|        45671|
# |CHANNEL|HNH363182|8CC84B57C265|        45669|
# |CHANNEL|SGH453702|84AA9C45C32B|        45669|
# |CHANNEL|NDFD22892|8CC84B419FB1|        45667|
# |CHANNEL|BGFD09819|B046FCC4142D|        45666|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220423.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |    VOD|DBD001368|5CBAEF93A9B1|        14209|
# |    VOD|HNH659026|08674EDF2F9C|        14006|
# |    VOD|TBD004757|B84DEED905FF|         9992|
# |    VOD|SGH470518|84AA9C45C366|        13779|
# |    VOD|BDD035730|485F992BDE44|        14700|
# |    VOD|SGD760432|28565A20C916|        33336|
# |    VOD|HNJ039182|B84DEEDD0C3A|        16171|
# |    VOD|SGFD27980|B84DEED144D4|          135|
# |    VOD|HPD035634|B046FCB65502|        11086|
# |    VOD|HNH590455|0C96E66A3AD9|         8513|
# |    VOD|SGD451651|B84DEED144F1|        19204|
# |    VOD|HNJ046541|10394E233396|        12354|
# |    VOD|VTD027012|08674EF71FD1|        14179|
# |    VOD|HND578210|B84DEED2C8D3|         4966|
# |    VOD|SGD432817|B84DEED3DEC1|        25830|
# |    VOD|SGAAE2779|B4B5B6FCA9DE|         1737|
# |    VOD|HND193197|CCEDDC14D0E1|        34291|
# |    VOD|SGFD68542|B046FCB61C5D|        16407|
# |    VOD|BDFD50321|B046FCBB178F|        49255|
# |    VOD|SGH360150|5413794C40C8|        33230|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220424.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|SGD803734|B046FCAD1947|        42805|
# |CHANNEL|THD006202|B05216130E89|        42690|
# |CHANNEL|BGD023126|B046FCC0AA31|        42689|
# |CHANNEL|DAH008942|B84DEED228C4|        42687|
# |CHANNEL|HNFD91677|84AA9C28AB2A|        42686|
# |CHANNEL|HND369456|5CEA1D0A4377|        42685|
# |CHANNEL|HDFD39087|0C96E6573221|        42684|
# |CHANNEL|NAFD10653|1CBFC03D8AF5|        42683|
# |CHANNEL|TNFD35204|5CBAEF93AC82|        42682|
# |CHANNEL|BID018264|B046FCB7E4F6|        42680|
# |CHANNEL|HDFD04973|B84DEE8A1B2A|        42679|
# |CHANNEL|SGH017988|B046FCB2E706|        42678|
# |CHANNEL|DND027331|10394E3D8AE1|        42677|
# |CHANNEL|HND594379|5CBAEF93B338|        42676|
# |CHANNEL|QIFD10281|D81265C8ED84|        42676|
# |CHANNEL|NBFD13727|08674EF37ACD|        42674|
# |CHANNEL|YBFD06137|08674EE206A9|        42673|
# |CHANNEL|VTH005990|10394E17C094|        42672|
# |CHANNEL|TGFD20696|CCEDDC5E2B00|        42672|
# |CHANNEL|HPFD59772|485F998229CD|        42670|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220425.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |  CHILD|LCFD15817|10394E42376B|           97|
# |  CHILD|DAFD22359|28565A38ABA9|        10514|
# |  CHILD|LDFD19141|802BF9E0DB40|        10168|
# |  CHILD|STFD15699|B84DEED1FC02|          154|
# |  CHILD|HND455769|B84DEED2CCF8|         8461|
# |  CHILD|DNH059511|B84DEED3E948|          319|
# |  CHILD|HNJ009389|B84DEEF5AB29|          107|
# |  CHILD|NTD038187|D46A6A45DA27|         7238|
# |  CHILD|BDD005332|B046FCB1669E|        17827|
# |  CHILD|HNH205703|B046FCB8AF3C|        11596|
# |  CHILD|HNH382199|F8DA0C5ACA37|         3797|
# |  CHILD|BDFD21226|08674EDFD7DA|         5537|
# |  CHILD|NBFD16748|08674EE94E47|         4954|
# |  CHILD|SGH476779|08674EF7CA9D|         2204|
# |  CHILD|SGH584438|0C96E657460D|        16689|
# |  CHILD|SGH591807|0C96E68E4D92|         5949|
# |  CHILD|NTD021464|0C96E6AA1B33|         6625|
# |  CHILD|DAFD36392|D46A6AED9AB2|        23495|
# |  CHILD|NTFD02669|E4AB893245F7|         5185|
# |  CHILD|DAFD38258|84AA9C35113C|         5765|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220426.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|NDFD09217|D80F99183B58|        10446|
# |CHANNEL|HNH868242|B84DEE8A38CA|        10528|
# |CHANNEL|HNJ168784|B84DEED89586|        10528|
# |CHANNEL|        0|B84DEED2D467|        10573|
# |CHANNEL|HDFD22731|08674EE95FDE|        10527|
# |CHANNEL|HNH467255|5CEA1D0A40FB|        10572|
# |CHANNEL|HNH615250|485F994D6D13|        10473|
# |CHANNEL|LAFD07815|9C305B3760F4|        10473|
# |CHANNEL|BTFD42022|B84DEED23B94|        10572|
# |CHANNEL|HND735472|B052161310CA|        10473|
# |CHANNEL|AGFD41906|CCEDDC5E39D5|        10572|
# |CHANNEL|SGH609912|485F994DA4E0|        10526|
# |CHANNEL|SGH945517|B84DEED288D5|        10526|
# |CHANNEL|SGH704972|08674EE8EEDC|        10525|
# |CHANNEL|THFD08742|5CEA1D0A22F1|        10571|
# |CHANNEL|HNH365039|B84DEECB4CB6|        10525|
# |CHANNEL|NTFD85425|B84DEECB789A|        10571|
# |CHANNEL|HNH902045|18473D53F482|        10524|
# |CHANNEL|HNH416550|D46A6AED8923|        10496|
# |CHANNEL|SGH096863|B046FCB89079|        10524|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220427.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|NTH008092|B84DEEDCC70D|         2153|
# |CHANNEL|NTFD94275|B84DEEEF27F1|         2166|
# |CHANNEL|SLFD11749|08674EE93B90|         2166|
# |CHANNEL|SGH959135|B84DEED26D96|         2166|
# |CHANNEL|SGH956502|B84DEED31C41|         2166|
# |CHANNEL|HPD079094|B84DEED35DDA|         2166|
# |CHANNEL|QNFD20114|A86BAD742989|         2166|
# |CHANNEL|NNFD18250|10394E139ABC|         2166|
# |CHANNEL|DAFD14458|B046FCB987C1|         2166|
# |CHANNEL|PTFD25998|10394E422347|         2166|
# |CHANNEL|QTFD07278|08674EF7CE33|         2165|
# |CHANNEL|HPD006215|10394E4B5630|         2165|
# |CHANNEL|HNH768376|B84DEEF59D5B|         2165|
# |CHANNEL|HND727611|8CC84B57D5C3|         2165|
# |CHANNEL|DBFD00640|0C96E62FCA8A|         2165|
# |CHANNEL|CTFD51127|B84DEED31E1C|         2165|
# |CHANNEL|HNH023251|4CEBBD201EAC|         2165|
# |CHANNEL|BDH007653|CCD4A1F36052|         2165|
# |CHANNEL|HNH608983|0C96E6EAD46B|         2165|
# |CHANNEL|SLFD10683|B84DEE84B034|         2153|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220428.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HNH700659|08674EE9564D|        20399|
# |CHANNEL|HNH858922|10394E1364D5|        20398|
# |CHANNEL|HNH638863|08674EDEA7C1|        20398|
# |CHANNEL|HNH969007|E89EB419C363|        20096|
# |CHANNEL|LAFD22648|CCEDDC3331C9|        20475|
# |CHANNEL|NAFD08593|4CEBBD1B594B|        20095|
# |CHANNEL|QNFD06520|84AA9C426521|        20095|
# |CHANNEL|HUD001823|F8DA0C2A41AE|        20095|
# |CHANNEL|BTD015286|10394E4B1F07|        20095|
# |CHANNEL|QNAAA1787|10394E420901|        20095|
# |CHANNEL|HNH057333|08674EDEB366|        20094|
# |CHANNEL|BTD029699|B046FCC102CF|        20094|
# |CHANNEL|SGH611763|485F994DA82D|        20471|
# |CHANNEL|HPD065816|B046FCB46203|        20093|
# |CHANNEL|BGAAA2405|10394E420C14|        20470|
# |CHANNEL|SGH730949|E4AB8927C224|        20469|
# |CHANNEL|BDH012376|E4AB8927AAB3|        20396|
# |CHANNEL|LSFD15505|B84DEEF614FA|        20157|
# |CHANNEL|LSFD07158|84AA9C3FFD9F|        20156|
# |CHANNEL|PYD010843|0C96E6E852A0|        20468|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220429.json
# ------------------------------------------
# Retrieving data from source
# ------------------------------------------
# +-------+---------+------------+-------------+
# |AppName| Contract|         Mac|TotalDuration|
# +-------+---------+------------+-------------+
# |CHANNEL|HNH757497|405BD8A648C6|        77713|
# |CHANNEL|LDFD14107|802BF9BE4376|        77712|
# |CHANNEL|SGH538814|802BF95B0E77|        78677|
# |CHANNEL|HND368630|4CEBBD201707|        77706|
# |CHANNEL|BDFD59880|0C96E68E61CD|        77704|
# |CHANNEL|HPFD87960|B84DEE853CE4|        78671|
# |CHANNEL|PYFD06964|0C96E6E85735|        77695|
# |CHANNEL|NDFD38001|10394E17356B|        78666|
# |CHANNEL|TVFD15974|10394E19A57E|        78665|
# |CHANNEL|HUFD27559|0C96E6C977A8|        77688|
# |CHANNEL|        0|B84DEED1CDF1|        78660|
# |CHANNEL|NBFD20938|18473D8EB55B|        78659|
# |CHANNEL|QTFD09280|CCEDDC5E4619|        78657|
# |CHANNEL|NAFD13566|485F994D7301|        77684|
# |CHANNEL|BEFD11586|E4AB897E0996|        78654|
# |CHANNEL|THFD22286|CCD4A1FA9A6C|        78654|
# |CHANNEL|NTD041113|E4AB8974D72B|        77674|
# |CHANNEL|HNH046808|B84DEE89BD13|        78648|
# |CHANNEL|TQFD09378|0C96E6AA1707|        78646|
# |CHANNEL|SGH649915|08674EDE1170|        77664|
# +-------+---------+------------+-------------+
# only showing top 20 rows
#
# Processed data of 20220430.json
# ------------------------------------------
# Categorizing data
# ------------------------------------------
# +-------+---------+------------+-------------+-----------+
# |AppName| Contract|         Mac|TotalDuration|       Type|
# +-------+---------+------------+-------------+-----------+
# |  KPLUS|HNH579912|0C96E62FC55C|          254|Truyền Hình|
# |  KPLUS|HUFD40665|CCEDDC333614|         1457|Truyền Hình|
# |  KPLUS|HNH572635|B068E6A1C5F6|         2318|Truyền Hình|
# |  KPLUS|HND141717|08674EE8D2C2|         1452|Truyền Hình|
# |  KPLUS|HNH743103|402343C25D7D|          251|Truyền Hình|
# |  KPLUS|HNH893773|B84DEE76D3B8|          924|Truyền Hình|
# |  KPLUS|HND083642|B84DEE849A0F|         1444|Truyền Hình|
# |  KPLUS|DNFD74404|90324BB44C39|          691|Truyền Hình|
# |  KPLUS|DTFD21200|B84DEED27709|         1436|Truyền Hình|
# |  KPLUS|LDFD05747|0C96E6C95E53|         1434|Truyền Hình|
# |  KPLUS|HNH063566|B84DEEDD1C85|          687|Truyền Hình|
# |  KPLUS|HNH866786|10394E2790A5|          248|Truyền Hình|
# |  KPLUS|NBAAA1128|10394E47C1AF|          247|Truyền Hình|
# |  KPLUS|HNH960439|B84DEED34371|          683|Truyền Hình|
# |  KPLUS|HNJ035736|CCD4A1FA86A5|          246|Truyền Hình|
# |  KPLUS|NTFD93673|B84DEEEF4763|         2288|Truyền Hình|
# |  KPLUS|HNJ063267|10394E172CA7|         2282|Truyền Hình|
# |  KPLUS|HNH790383|4CEBBD53378B|          906|Truyền Hình|
# |  KPLUS|THFD12466|5CEA1D893E1C|          242|Truyền Hình|
# |  KPLUS|HNH566080|802BF9E0DDC0|          242|Truyền Hình|
# +-------+---------+------------+-------------+-----------+
# only showing top 20 rows
#
# ------------------------------------------
# Finalizing data
# ------------------------------------------
# +---------+-----------+-------------+
# | Contract|       Type|TotalDuration|
# +---------+-----------+-------------+
# |HNH579912|Truyền Hình|          254|
# |HUFD40665|Truyền Hình|         1457|
# |HNH572635|Truyền Hình|         2318|
# |HND141717|Truyền Hình|         1452|
# |HNH743103|Truyền Hình|          251|
# |HNH893773|Truyền Hình|          924|
# |HND083642|Truyền Hình|         1444|
# |DNFD74404|Truyền Hình|          691|
# |DTFD21200|Truyền Hình|         1436|
# |LDFD05747|Truyền Hình|         1434|
# |HNH063566|Truyền Hình|          687|
# |HNH866786|Truyền Hình|          248|
# |NBAAA1128|Truyền Hình|          247|
# |HNH960439|Truyền Hình|          683|
# |HNJ035736|Truyền Hình|          246|
# |NTFD93673|Truyền Hình|         2288|
# |HNJ063267|Truyền Hình|         2282|
# |HNH790383|Truyền Hình|          906|
# |THFD12466|Truyền Hình|          242|
# |HNH566080|Truyền Hình|          242|
# +---------+-----------+-------------+
# only showing top 20 rows
#
# ------------------------------------------
# Pivoting data
# ------------------------------------------
# +---------+-----+--------+-----------+---------+--------+-----------+
# | Contract|Error|Giải Trí|Phim Truyện|Thiếu Nhi|Thể Thao|Truyền Hình|
# +---------+-----+--------+-----------+---------+--------+-----------+
# |HTFD11598| null|    null|      15551|     null|    null|      42919|
# |HPFD48556| null|      69|       null|     null|    null|    1468328|
# |NBFD10014| null|    null|       null|     null|    null|    1596494|
# |HNH619088| null|    null|      77275|    11361|    null|     917930|
# |HNH036174| null|    null|      62674|     null|    null|     354879|
# |DNH067877| null|    null|       null|     null|    null|     181308|
# |SGH806190| null|    null|       null|     null|    null|     217779|
# |HNH582022| null|    null|       null|     null|    null|    2209949|
# |HNH795510| null|    null|      30197|      265|    null|    1196936|
# |DNFD91557| null|    null|       null|     null|    null|      95567|
# |SGH266908| null|    null|       null|     1636|    null|     112771|
# |HNJ102653| null|    null|       null|     null|    null|     166767|
# |HDFD42710| null|    null|       null|     null|    null|     494456|
# |SGH674576| null|    null|       5437|     null|    null|     364296|
# |DNH034235| null|    null|       null|     null|    null|     139582|
# |NDFD32943| null|    null|       null|     1077|    null|     188793|
# |TNFD30439| null|    null|       null|     null|    null|      48193|
# |DNH083321| null|    null|       null|     null|    null|      86343|
# |SGH446342| null|    null|       null|     null|    null|     502707|
# |DLFD14250| null|    null|      29144|     null|    null|     391492|
# +---------+-----+--------+-----------+---------+--------+-----------+
# only showing top 20 rows
#
# Task Run successfully
